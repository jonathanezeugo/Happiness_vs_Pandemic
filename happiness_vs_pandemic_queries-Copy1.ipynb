# %%
import pandas as pd
import numpy as np
import datetime as dt
import sqlalchemy
from sqlalchemy import create_engine
from secrets import username, password
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # UN Data #

# %%
# load un_govt.csv
un_govt= pd.read_csv("./data/un_govt.csv")
un_govt
# Out:
#      Unnamed: 0      country  population_2020 constitutional_form  \
# 0             0  Afghanistan         39074280            Republic
# 1             1      Albania          2877239            Republic
# 2             2      Algeria         43984569            Republic
# 3             3    Argentina         45267449            Republic
# 4             4      Armenia          2964219            Republic
# ..          ...          ...              ...                 ...
# 131         136    Venezuela         28421581            Republic
# 132         137      Vietnam         97490013            Republic
# 133         138        Yemen         29935468         Provisional
# 134         139       Zambia         18468257            Republic
# 135         140     Zimbabwe         14899771            Republic
#
#                                          head_of_state  \
# 0                                            Executive
# 1                                           Ceremonial
# 2                                            Executive
# 3                                            Executive
# 4                                           Ceremonial
# ..                                                 ...
# 131                                          Executive
# 132                                          Executive
# 133  No constitutionally-defined basis to current r...
# 134                                          Executive
# 135                                          Executive
#
#                          basis_of_executive_legitimacy     id
# 0             Presidency is independent of legislature  30000
# 1      Ministry is subject to parliamentary confidence  30001
# 2    Presidency independent of legislature; ministr...  30002
# 3             Presidency is independent of legislature  30003
# 4      Ministry is subject to parliamentary confidence  30004
# ..                                                 ...    ...
# 131           Presidency is independent of legislature  30181
# 132  Power constitutionally linked to a single poli...  30182
# 133  No constitutionally-defined basis to current r...  30183
# 134           Presidency is independent of legislature  30184
# 135           Presidency is independent of legislature  30185
#
# [136 rows x 7 columns]

# %%
un_govt = un_govt.drop(columns = ['Unnamed: 0'])

# %%
un_govt.dtypes
# Out:
# country                          object
# population_2020                   int64
# constitutional_form              object
# head_of_state                    object
# basis_of_executive_legitimacy    object
# id                                int64
# dtype: object

# %% [markdown]
# # happiness data #

# %%
# load world_happiness
world_happiness = "./data/world_happiness.csv"
world_happiness = pd.read_csv(world_happiness)
world_happiness
# Out:
#      Unnamed: 0  country_id                        world_region  \
# 0             0       30000                          South Asia
# 1             1       30001          Central and Eastern Europe
# 2             2       30002        Middle East and North Africa
# 3             3       30003         Latin America and Caribbean
# 4             4       30004  Commonwealth of Independent States
# ..          ...         ...                                 ...
# 131         131       30181         Latin America and Caribbean
# 132         132       30182                      Southeast Asia
# 133         133       30183        Middle East and North Africa
# 134         134       30184                  Sub-Saharan Africa
# 135         135       30185                  Sub-Saharan Africa
#
#      happiness_score  gdp_per_capita  social_support  healthy_life_expectancy  \
# 0             2.5669        7.462861        0.470367                52.590000
# 1             4.8827        9.417931        0.671070                68.708138
# 2             5.0051        9.537965        0.803385                65.905174
# 3             5.9747        9.810955        0.900568                68.803802
# 4             4.6768        9.100476        0.757479                66.750656
# ..               ...             ...             ...                      ...
# 131           5.0532        8.977794        0.890408                66.505341
# 132           5.3535        8.809546        0.849987                67.952736
# 133           3.5274        7.759683        0.817981                56.727283
# 134           3.7594        8.224720        0.698824                55.299377
# 135           3.2992        7.865712        0.763093                55.617260
#
#      freedom_of_choice  generosity  perceptions_of_corruption   year_2020
# 0             0.396573   -0.096429                   0.933687  2020-01-01
# 1             0.781994   -0.042309                   0.896304  2020-01-01
# 2             0.466611   -0.121105                   0.735485  2020-01-01
# 3             0.831132   -0.194914                   0.842010  2020-01-01
# 4             0.712018   -0.138780                   0.773545  2020-01-01
# ..                 ...         ...                        ...         ...
# 131           0.623278   -0.169091                   0.837038  2020-01-01
# 132           0.939593   -0.094533                   0.796421  2020-01-01
# 133           0.599920   -0.157735                   0.800288  2020-01-01
# 134           0.806500    0.078037                   0.801290  2020-01-01
# 135           0.711458   -0.072064                   0.810237  2020-01-01
#
# [136 rows x 11 columns]

# %%
world_happiness = world_happiness.drop(columns = ['Unnamed: 0'])

# %%
world_happiness.dtypes
# Out:
# country_id                     int64
# world_region                  object
# happiness_score              float64
# gdp_per_capita               float64
# social_support               float64
# healthy_life_expectancy      float64
# freedom_of_choice            float64
# generosity                   float64
# perceptions_of_corruption    float64
# year_2020                     object
# dtype: object

# %% [markdown]
# # covid data #

# %%
# import csv as df

world_covid_data = pd.read_csv("./data/world_covid_data.csv")
world_covid_data.tail()
# Out:
#        Unnamed: 0  country_id  covid_cases_id        date  new_cases  \
# 41669       41670       30185         59829.0  2020-06-20        0.0
# 41670       41671       30185         59830.0  2020-06-19       16.0
# 41671       41672       30185         59831.0  2020-06-18       62.0
# 41672       41673       30185         59832.0  2020-08-09       74.0
# 41673       41674       30185         59833.0  2020-12-31      242.0
#
#        new_deaths  extreme_poverty  handwashing_facilities  \
# 41669         0.0             21.4                  36.791
# 41670         0.0             21.4                  36.791
# 41671         0.0             21.4                  36.791
# 41672         2.0             21.4                  36.791
# 41673         3.0             21.4                  36.791
#
#        covid_times_life_expectancy
# 41669                        61.49
# 41670                        61.49
# 41671                        61.49
# 41672                        61.49
# 41673                        61.49

# %%
world_covid_data = world_covid_data.drop(columns = ['Unnamed: 0'])

# %%
# look at types

world_covid_data.dtypes
# Out:
# country_id                       int64
# covid_cases_id                 float64
# date                            object
# new_cases                      float64
# new_deaths                     float64
# extreme_poverty                float64
# handwashing_facilities         float64
# covid_times_life_expectancy    float64
# dtype: object

# %% [markdown]
# # govt response data #

# %%
# Read csv and store in to Pandas Dataframe
gov_response = pd.read_csv('./data/gov_response.csv')
gov_response
# Out:
#        Unnamed: 0  response_id  \
# 0               0        300.0
# 1               1        402.0
# 2               2        403.0
# 3               3        404.0
# 4               4        405.0
# ...           ...          ...
# 16170       16171      21554.0
# 16171       16172      21555.0
# 16172       16173      21556.0
# 16173       16174      21558.0
# 16174       16175      21584.0
#
#                                            gov_resp_desc gov_resp_date  \
# 0      March 6, Afghanistan "Measures have been taken...    2020-03-06
# 1      "On 26 March, the President of Afghanistan, As...    2020-03-26
# 2      In Afghanistan's "eastern province of Nangarha...    2020-03-28
# 3      Relaxation in the measured lockdown policies i...    2020-03-29
# 4      In Afghanistan, "On 1 April, the Kabul Chief o...    2020-04-01
# ...                                                  ...           ...
# 16170  Zimbabwe has introduced mandatory screening fo...    2020-07-22
# 16171  All vehicles used as a transport service in Zi...    2020-05-02
# 16172  Every individual must be temperature-tested an...    2020-05-02
# 16173  When an employee tests positive for COVID-19 i...    2020-07-22
# 16174  In Zimbabwe, the Zimbabwe International Trade ...    2020-03-17
#
#                          gov_resp_type                             enforcer  \
# 0         Anti-Disinformation Measures  Ministry/Department of Health,Other
# 1             Other Policy Not Listed                      National Governm
# 2             Other Policy Not Listed              Provincial/State Governm
# 3             Other Policy Not Listed              Provincial/State Governm
# 4             Other Policy Not Listed                                   NaN
# ...                                ...                                  ...
# 16170                   Health Testing                     National Governm
# 16171                           Hygien                 National Government,
# 16172                           Hygien                     National Governm
# 16173                           Hygien                 National Government,
# 16174  Restrictions of Mass Gatherings                     National Governm
#
#                                        gov_resp_link_src  country_id
# 0      https://www.etilaatroz.com/94246/fears-rumors-...       30000
# 1      https://reliefweb.int/report/afghanistan/afgha...       30000
# 2      https://www.nytimes.com/2020/03/31/world/asia/...       30000
# 3      https://reliefweb.int/report/afghanistan/afgha...       30000
# 4      https://reliefweb.int/report/afghanistan/afgha...       30000
# ...                                                  ...         ...
# 16170  https://twitter.com/edmnangagwa/status/1285955...       30185
# 16171  http://www.veritaszim.net/sites/veritas_d/file...       30185
# 16172  http://www.veritaszim.net/sites/veritas_d/file...       30185
# 16173  https://www.veritaszim.net/sites/veritas_d/fil...       30185
# 16174  https://iharare.com/independence-day-zitf-post...       30185
#
# [16175 rows x 8 columns]

# %%
gov_response = gov_response.drop(columns = ['Unnamed: 0'])

# %%
gov_response = gov_response.dropna()

# %%
# take a look at dtypes
gov_response.dtypes
# Out:
# response_id          float64
# gov_resp_desc         object
# gov_resp_date         object
# gov_resp_type         object
# enforcer              object
# gov_resp_link_src     object
# country_id             int64
# dtype: object

# %% [markdown]
# # SQL Alchemy #

# %%
from sqlalchemy import create_engine



engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/Happiness_db')
conn=engine.connect()

# %%
results=engine.execute("SELECT country FROM un_govt").fetchall()
country=[]
for result in results:
    country.append(result[0])

# %%
country
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahrain',
#  'Bangladesh',
#  'Belarus',
#  'Belgium',
#  'Benin',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Democratic Republic of the Congo',
#  'Costa Rica',
#  'Croatia',
#  'Cyprus',
#  'Denmark',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Estonia',
#  'Ethiopia',
#  'Finland',
#  'France',
#  'Gabon',
#  'Gambia',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Guatemala',
#  'Guinea',
#  'Haiti',
#  'Honduras',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'South Korea',
#  'Kuwait',
#  'Kyrgyzstan',
#  'Laos',
#  'Latvia',
#  'Lebanon',
#  'Lesotho',
#  'Liberia',
#  'Libya',
#  'Lithuania',
#  'Luxembourg',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Maldives',
#  'Mali',
#  'Malta',
#  'Mauritania',
#  'Mauritius',
#  'Mexico',
#  'Moldova',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Namibia',
#  'Nepal',
#  'Netherlands',
#  'New Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'Norway',
#  'Pakistan',
#  'Panama',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Russia',
#  'Rwanda',
#  'Saudi Arabia',
#  'Senegal',
#  'Sierra Leone',
#  'Singapore',
#  'Slovakia',
#  'Slovenia',
#  'Spain',
#  'Sri Lanka',
#  'Sweden',
#  'Switzerland',
#  'Tajikistan',
#  'Tanzania',
#  'Thailand',
#  'Togo',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Uganda',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Uruguay',
#  'Uzbekistan',
#  'Venezuela',
#  'Vietnam',
#  'Yemen',
#  'Zambia',
#  'Zimbabwe']

# %%
{id:country, constitutional form, population, world_region, gdp}

# %%
results=engine.execute("""select  u.id, u.country, u.constitutional_form, u.population_2020, w.world_region, w.gdp_per_capita
from un_govt as u
join world_happiness as w
on (u.id=w.country_id)""").fetchall()
for result in results:
    print(result)
# Out:
# (30000, 'Afghanistan', 'Republic', 39074280, 'South Asia', 7.462860584)
# (30001, 'Albania', 'Republic', 2877239, 'Central and Eastern Europe', 9.417930603)
# (30002, 'Algeria', 'Republic', 43984569, 'Middle East and North Africa', 9.537964821)
# (30003, 'Argentina', 'Republic', 45267449, 'Latin America and Caribbean', 9.810955048)
# (30004, 'Armenia', 'Republic', 2964219, 'Commonwealth of Independent States', 9.100476265)
# (30005, 'Australia', 'Constitutional\xa0monarchy', 25550683, 'North America and ANZ', 10.72059631)
# (30006, 'Austria', 'Republic', 9015361, 'Western Europe', 10.7428236)
# (30007, 'Azerbaijan', 'Republic', 10154978, 'Commonwealth of Independent States', 9.687726974)
# (30008, 'Bahrain', 'Constitutional\xa0monarchy', 1711057, 'Middle East and North Africa', 10.67638016)
# (30009, 'Bangladesh', 'Republic', 164972348, 'South Asia', 8.287063599)
# (30010, 'Belarus', 'Republic', 9448772, 'Commonwealth of Independent States', 9.779945374)
# (30011, 'Belgium', 'Constitutional\xa0monarchy', 11598451, 'Western Europe', 10.6736393)
# (30012, 'Benin', 'Republic', 12175480, 'Sub-Saharan Africa', 7.674319744)
# (30014, 'Bolivia', 'Republic', 11700207, 'Latin America and Caribbean', 8.851115227)
# (30015, 'Bosnia and Herzegovina', 'Republic', 3277152, 'Central and Eastern Europe', 9.455817223)
# (30016, 'Botswana', 'Republic', 2359585, 'Sub-Saharan Africa', 9.711203575)
# (30017, 'Brazil', 'Republic', 212821986, 'Latin America and Caribbean', 9.56643486)
# (30019, 'Bulgaria', 'Republic', 6939018, 'Central and Eastern Europe', 9.869318962)
# (30020, 'Burkina Faso', 'Republic', 20997293, 'Sub-Saharan Africa', 7.46854496)
# (30021, 'Burundi', 'Republic', 11948454, 'Sub-Saharan Africa', 6.492642403)
# (30022, 'Cambodia', 'Constitutional\xa0monarchy', 16758448, 'Southeast Asia', 8.249890327)
# (30023, 'Cameroon', 'Republic', 26655083, 'Sub-Saharan Africa', 8.118647575)
# (30024, 'Canada', 'Constitutional\xa0monarchy', 37799407, 'North America and ANZ', 10.69236851)
# (30026, 'Chad', 'Republic', 16502877, 'Sub-Saharan Africa', 7.467963696)
# (30027, 'Chile', 'Republic', 19144605, 'Latin America and Caribbean', 10.0320549)
# (30028, 'China', 'Republic', 1440297825, 'East Asia', 9.688568115)
# (30029, 'Colombia', 'Republic', 50976248, 'Latin America and Caribbean', 9.500369072)
# (30031, 'Democratic Republic of the Congo', 'Republic', 90003954, 'Sub-Saharan Africa', 6.694256306)
# (30033, 'Costa Rica', 'Republic', 5102158, 'Latin America and Caribbean', 9.658156395)
# (30035, 'Croatia', 'Republic', 4100719, 'Central and Eastern Europe', 10.07087517)
# (30037, 'Cyprus', 'Republic', 1208886, 'Western Europe', 10.40570259)
# (30039, 'Denmark', 'Constitutional\xa0monarchy', 5795780, 'Western Europe', 10.77400112)
# (30044, 'Ecuador', 'Republic', 17688599, 'Latin America and Caribbean', 9.246058464)
# (30045, 'Egypt', 'Republic', 102659126, 'Middle East and North Africa', 9.316541672)
# (30046, 'El Salvador', 'Republic', 6491923, 'Latin America and Caribbean', 8.909075737)
# (30049, 'Estonia', 'Republic', 1326693, 'Central and Eastern Europe', 10.34001732)
# (30051, 'Ethiopia', 'Republic', 115434444, 'Sub-Saharan Africa', 7.509385586)
# (30054, 'Finland', 'Republic', 5542237, 'Western Europe', 10.63926697)
# (30055, 'France', 'Republic', 65298930, 'Western Europe', 10.58422279)
# (30056, 'Gabon', 'Republic', 2234448, 'Sub-Saharan Africa', 9.680537224)
# (30057, 'Gambia', 'Republic', 2427782, 'Sub-Saharan Africa', 7.321814537)
# (30058, 'Georgia', 'Republic', 3987805, 'Commonwealth of Independent States', 9.226100922)
# (30059, 'Germany', 'Republic', 83830972, 'Western Europe', 10.7328186)
# (30060, 'Ghana', 'Republic', 31181428, 'Sub-Saharan Africa', 8.350645065)
# (30061, 'Greece', 'Republic', 10413936, 'Western Europe', 10.13232613)
# (30063, 'Guatemala', 'Republic', 17971382, 'Latin America and Caribbean', 8.924805641)
# (30064, 'Guinea', 'Republic', 13191279, 'Sub-Saharan Africa', 7.750990391)
# (30067, 'Haiti', 'Republic', 11426356, 'Latin America and Caribbean', 7.411329269)
# (30068, 'Honduras', 'Republic', 9931333, 'Latin America and Caribbean', 8.424534798)
# (30069, 'Hungary', 'Republic', 9655983, 'Central and Eastern Europe', 10.24924374)
# (30070, 'Iceland', 'Republic', 341628, 'Western Europe', 10.77255917)
# (30071, 'India', 'Republic', 1382345085, 'South Asia', 8.849823952)
# (30072, 'Indonesia', 'Republic', 274021604, 'Southeast Asia', 9.36975193)
# (30073, 'Iran', 'Republic', 84176929, 'Middle East and North Africa', 9.813719749)
# (30074, 'Iraq', 'Republic', 40372771, 'Middle East and North Africa', 9.661095619)
# (30075, 'Ireland', 'Republic', 4947267, 'Western Europe', 11.16097832)
# (30076, 'Israel', 'Republic', 8678517, 'Middle East and North Africa', 10.41752529)
# (30077, 'Italy', 'Republic', 60446035, 'Western Europe', 10.48183632)
# (30078, 'Jamaica', 'Constitutional\xa0monarchy', 2963429, 'Latin America and Caribbean', 9.006250381)
# (30079, 'Japan', 'Constitutional\xa0monarchy', 126407422, 'East Asia', 10.57968903)
# (30080, 'Jordan', 'Constitutional\xa0monarchy', 10220604, 'Middle East and North Africa', 9.025999069)
# (30081, 'Kazakhstan', 'Republic', 18815231, 'Commonwealth of Independent States', 10.11465836)
# (30082, 'Kenya', 'Republic', 53968739, 'Sub-Saharan Africa', 8.02977562)
# (30085, 'South Korea', 'Republic', 51276977, 'East Asia', 10.51056671)
# (30086, 'Kuwait', 'Constitutional\xa0monarchy', 4281320, 'Middle East and North Africa', 11.08982468)
# (30087, 'Kyrgyzstan', 'Republic', 6542426, 'Commonwealth of Independent States', 8.148405075)
# (30088, 'Laos', 'Republic', 7293542, 'Southeast Asia', 8.79858017)
# (30089, 'Latvia', 'Republic', 1882408, 'Central and Eastern Europe', 10.17531967)
# (30090, 'Lebanon', 'Republic', 6819976, 'Middle East and North Africa', 9.3617239)
# (30091, 'Lesotho', 'Constitutional\xa0monarchy', 2145194, 'Sub-Saharan Africa', 7.960488319)
# (30092, 'Liberia', 'Republic', 5077411, 'Sub-Saharan Africa', 7.054380417)
# (30093, 'Libya', 'Provisional', 6887247, 'Middle East and North Africa', 9.789815903)
# (30095, 'Lithuania', 'Republic', 2715340, 'Central and Eastern Europe', 10.34362602)
# (30096, 'Luxembourg', 'Constitutional\xa0monarchy', 627704, 'Western Europe', 11.45068073)
# (30097, 'Madagascar', 'Republic', 27808395, 'Sub-Saharan Africa', 7.281685829)
# (30098, 'Malawi', 'Republic', 19211425, 'Sub-Saharan Africa', 7.062226295)
# (30099, 'Malaysia', 'Constitutional\xa0monarchy', 32436963, 'Southeast Asia', 10.26251888)
# (30100, 'Maldives', 'Republic', 542151, 'South Asia', 9.518632889)
# (30101, 'Mali', 'Provisional', 20346106, 'Sub-Saharan Africa', 7.629852295)
# (30102, 'Malta', 'Republic', 441750, 'Western Europe', 10.53383827)
# (30104, 'Mauritania', 'Republic', 4669775, 'Sub-Saharan Africa', 8.233919144)
# (30105, 'Mauritius', 'Republic', 1272140, 'Sub-Saharan Africa', 9.956786156)
# (30106, 'Mexico', 'Republic', 129166028, 'Latin America and Caribbean', 9.797797203)
# (30107, 'Moldova', 'Republic', 4032294, 'Commonwealth of Independent States', 8.776714325)
# (30109, 'Mongolia', 'Republic', 3287242, 'East Asia', 9.412186623)
# (30110, 'Montenegro', 'Republic', 628080, 'Central and Eastern Europe', 9.751860619)
# (30111, 'Morocco', 'Constitutional\xa0monarchy', 36985624, 'Middle East and North Africa', 8.940313339)
# (30112, 'Mozambique', 'Republic', 31398811, 'Sub-Saharan Africa', 7.069345951)
# (30113, 'Myanmar', 'Provisional', 54473253, 'Southeast Asia', 8.680481911)
# (30114, 'Namibia', 'Republic', 2548663, 'Sub-Saharan Africa', 9.203141212)
# (30116, 'Nepal', 'Republic', 29225196, 'South Asia', 7.925357342)
# (30117, 'Netherlands', 'Constitutional\xa0monarchy', 17141544, 'Western Europe', 10.81271172)
# (30118, 'New Zealand', 'Constitutional\xa0monarchy', 4829021, 'North America and ANZ', 10.50094318)
# (30119, 'Nicaragua', 'Republic', 6638075, 'Latin America and Caribbean', 8.493160248)
# (30120, 'Niger', 'Republic', 24346468, 'Sub-Saharan Africa', 6.842166901)
# (30121, 'Nigeria', 'Republic', 206984347, 'Sub-Saharan Africa', 8.57662487)
# (30123, 'Norway', 'Constitutional\xa0monarchy', 5428594, 'Western Europe', 11.08780384)
# (30125, 'Pakistan', 'Republic', 221612785, 'South Asia', 8.482727051)
# (30128, 'Panama', 'Republic', 4326296, 'Latin America and Caribbean', 10.03423405)
# (30130, 'Paraguay', 'Republic', 7147553, 'Latin America and Caribbean', 9.389982224)
# (30131, 'Peru', 'Republic', 33050211, 'Latin America and Caribbean', 9.456313133)
# (30132, 'Philippines', 'Republic', 109830324, 'Southeast Asia', 8.993545532)
# (30133, 'Poland', 'Republic', 37839255, 'Central and Eastern Europe', 10.26512432)
# (30134, 'Portugal', 'Republic', 10191409, 'Western Europe', 10.26374245)
# (30136, 'Romania', 'Republic', 19214608, 'Central and Eastern Europe', 10.107584)
# (30137, 'Russia', 'Republic', 145945524, 'Commonwealth of Independent States', 10.12887192)
# (30138, 'Rwanda', 'Republic', 13005303, 'Sub-Saharan Africa', 7.600104332)
# (30144, 'Saudi Arabia', 'Absolute monarchy', 34905942, 'Middle East and North Africa', 10.79781246)
# (30145, 'Senegal', 'Republic', 16816539, 'Sub-Saharan Africa', 8.118982315)
# (30148, 'Sierra Leone', 'Republic', 8004158, 'Sub-Saharan Africa', 7.26880312)
# (30149, 'Singapore', 'Republic', 5858322, 'Southeast Asia', 11.39552116)
# (30150, 'Slovakia', 'Republic', 5460109, 'Central and Eastern Europe', 10.34774971)
# (30151, 'Slovenia', 'Republic', 2078989, 'Central and Eastern Europe', 10.39232254)
# (30156, 'Spain', 'Constitutional\xa0monarchy', 46757980, 'Western Europe', 10.46292686)
# (30157, 'Sri Lanka', 'Republic', 21428970, 'South Asia', 9.389969826)
# (30160, 'Sweden', 'Constitutional\xa0monarchy', 10110233, 'Western Europe', 10.75879383)
# (30161, 'Switzerland', 'Republic', 8665615, 'Western Europe', 10.97993279)
# (30163, 'Tajikistan', 'Republic', 9573310, 'Commonwealth of Independent States', 8.024810791)
# (30164, 'Tanzania', 'Republic', 60012400, 'Sub-Saharan Africa', 7.967665195)
# (30165, 'Thailand', 'Constitutional\xa0monarchy', 69830779, 'Southeast Asia', 9.741791725)
# (30166, 'Togo', 'Republic', 8310934, 'Sub-Saharan Africa', 7.357711315)
# (30168, 'Trinidad and Tobago', 'Republic', 1400283, 'Latin America and Caribbean', 10.26000214)
# (30169, 'Tunisia', 'Republic', 11839918, 'Middle East and North Africa', 9.314972878)
# (30170, 'Turkey', 'Republic', 84495243, 'Middle East and North Africa', 10.12941933)
# (30173, 'Uganda', 'Republic', 45974931, 'Sub-Saharan Africa', 7.500389576)
# (30174, 'Ukraine', 'Republic', 43686577, 'Commonwealth of Independent States', 9.010690689)
# (30175, 'United Arab Emirates', 'Constitutional\xa0monarchy', 9910892, 'Middle East and North Africa', 11.1099987)
# (30176, 'United Kingdom', 'Constitutional\xa0monarchy', 67948282, 'Western Europe', 10.60013485)
# (30177, 'United States', 'Republic', 331341050, 'North America and ANZ', 10.92576885)
# (30178, 'Uruguay', 'Republic', 3475842, 'Latin America and Caribbean', 9.948192596)
# (30179, 'Uzbekistan', 'Republic', 33551824, 'Commonwealth of Independent States', 8.740371704)
# (30181, 'Venezuela', 'Republic', 28421581, 'Latin America and Caribbean', 8.977793694)
# (30182, 'Vietnam', 'Republic', 97490013, 'Southeast Asia', 8.809545517)
# (30183, 'Yemen', 'Provisional', 29935468, 'Middle East and North Africa', 7.759682655)
# (30184, 'Zambia', 'Republic', 18468257, 'Sub-Saharan Africa', 8.224720001)
# (30185, 'Zimbabwe', 'Republic', 14899771, 'Sub-Saharan Africa', 7.865711689)

# %%
govt = pd.read_sql("SELECT * FROM un_govt", conn )
govt.head()
# Out:
#       id      country  population_2020 head_of_state constitutional_form  \
# 0  30000  Afghanistan         39074280     Executive            Republic
# 1  30001      Albania          2877239    Ceremonial            Republic
# 2  30002      Algeria         43984569     Executive            Republic
# 3  30003    Argentina         45267449     Executive            Republic
# 4  30004      Armenia          2964219    Ceremonial            Republic
#
#                        basis_of_executive_legitimacy
# 0           Presidency is independent of legislature
# 1    Ministry is subject to parliamentary confidence
# 2  Presidency independent of legislature; ministr...
# 3           Presidency is independent of legislature
# 4    Ministry is subject to parliamentary confidence

# %%
demographics=[]

for result in results:
    country_data={}
    country_data["id"] = result[0]
    country_data["country_name"] = result[1]
    country_data["type_of_government"] = result[2]
    country_data["population"] = result[3]
    country_data["world_region"] = result[4]
    country_data["gdp"] = result[5]
    
    demographics.append(country_data)

# %%
print(demographics)
# Out:
# [{'id': 30000, 'country_name': 'Afghanistan', 'type_of_government': 'Republic', 'population': 39074280, 'world_region': 'South Asia', 'gdp': 7.462860584}, {'id': 30001, 'country_name': 'Albania', 'type_of_government': 'Republic', 'population': 2877239, 'world_region': 'Central and Eastern Europe', 'gdp': 9.417930603}, {'id': 30002, 'country_name': 'Algeria', 'type_of_government': 'Republic', 'population': 43984569, 'world_region': 'Middle East and North Africa', 'gdp': 9.537964821}, {'id': 30003, 'country_name': 'Argentina', 'type_of_government': 'Republic', 'population': 45267449, 'world_region': 'Latin America and Caribbean', 'gdp': 9.810955048}, {'id': 30004, 'country_name': 'Armenia', 'type_of_government': 'Republic', 'population': 2964219, 'world_region': 'Commonwealth of Independent States', 'gdp': 9.100476265}, {'id': 30005, 'country_name': 'Australia', 'type_of_government': 'Constitutional\xa0monarchy', 'population': 25550683, 'world_region': 'North America and ANZ', 'gdp': 10.72059631}, {'id': 30006, 'country_name': 'Austria', 'type_of_government': 'Republic', 'population': 9015361, 'world_region': 'Western Europe', 'gdp': 10.7428236}, {'id': 30007, 'country_name': 'Azerbaijan', 'type_of_government': 'Republic', 'population': 10154978, 'world_region': 'Commonwealth of Independent States', 'gdp': 9.687726974}, {'id': 30008, 'country_name': 'Bahrain', 'type_of_government': 'Constitutional\xa0monarchy', 'population': 1711057, 'world_region': 'Middle East and North Africa', 'gdp': 10.67638016}, {'id': 30009, 'country_name': 'Bangladesh', 'type_of_government': 'Republic', 'population': 164972348, 'world_region': 'South Asia', 'gdp': 8.287063599}, {'id': 30010, 'country_name': 'Belarus', 'type_of_government': 'Republic', 'population': 9448772, 'world_region': 'Commonwealth of Independent States', 'gdp': 9.779945374}, {'id': 30011, 'country_name': 'Belgium', 'type_of_government': 'Constitutional\xa0monarchy', 'population': 11598451, 'world_region': 'Western Europe', 'gdp': 10.6736393}, {'id': 30012, 'country_name': 'Benin', 'type_of_government': 'Republic', 'population': 12175480, 'world_region': 'Sub-Saharan Africa', 'gdp': 7.674319744}, {'id': 30014, 'country_name': 'Bolivia', 'type_of_government': 'Republic', 'population': 11700207, 'world_region': 'Latin America and Caribbean', 'gdp': 8.851115227}, {'id': 30015, 'country_name': 'Bosnia and Herzegovina', 'type_of_government': 'Republic', 'population': 3277152, 'world_region': 'Central and Eastern Europe', 'gdp': 9.455817223}, {'id': 30016, 'country_name': 'Botswana', 'type_of_government': 'Republic', 'population': 2359585, 'world_region': 'Sub-Saharan Africa', 'gdp': 9.711203575}, {'id': 30017, 'country_name': 'Brazil', 'type_of_government': 'Republic', 'population': 212821986, 'world_region': 'Latin America and Caribbean', 'gdp': 9.56643486}, {'id': 30019, 'country_name': 'Bulgaria', 'type_of_government': 'Republic', 'population': 6939018, 'world_region': 'Central and Eastern Europe', 'gdp': 9.869318962}, {'id': 30020, 'country_name': 'Burkina Faso', 'type_of_government': 'Republic', 'population': 20997293, 'world_region': 'Sub-Saharan Africa', 'gdp': 7.46854496}, {'id': 30021, 'country_name': 'Burundi', 'type_of_government': 'Republic', 'population': 11948454, 'world_region': 'Sub-Saharan Africa', 'gdp': 6.492642403}, {'id': 30022, 'country_name': 'Cambodia', 'type_of_government': 'Constitutional\xa0monarchy', 'population': 16758448, 'world_region': 'Southeast Asia', 'gdp': 8.249890327}, {'id': 30023, 'country_name': 'Cameroon', 'type_of_government': 'Republic', 'population': 26655083, 'world_region': 'Sub-Saharan Africa', 'gdp': 8.118647575}, {'id': 30024, 'country_name': 'Canada', 'type_of_government': 'Constitutional\xa0monarchy', 'population': 37799407, 'world_region': 'North America and ANZ', 'gdp': 10.69236851}, {'id': 30026, 'country_name': 'Chad', 'type_of_government': 'Republic', 'population': 16502877, 'world_region': 'Sub-Saharan Africa', 'gdp': 7.467963696}, ...

# %%
world_hap = pd.read_sql("SELECT * FROM world_happiness" , conn )
world_hap
# Out:
#      country_id   year_2020                        world_region  \
# 0         30000  2020-01-01                          South Asia
# 1         30001  2020-01-01          Central and Eastern Europe
# 2         30002  2020-01-01        Middle East and North Africa
# 3         30003  2020-01-01         Latin America and Caribbean
# 4         30004  2020-01-01  Commonwealth of Independent States
# ..          ...         ...                                 ...
# 131       30181  2020-01-01         Latin America and Caribbean
# 132       30182  2020-01-01                      Southeast Asia
# 133       30183  2020-01-01        Middle East and North Africa
# 134       30184  2020-01-01                  Sub-Saharan Africa
# 135       30185  2020-01-01                  Sub-Saharan Africa
#
#      gdp_per_capita  happiness_score  social_support  healthy_life_expectancy  \
# 0          7.462861           2.5669        0.470367                52.590000
# 1          9.417931           4.8827        0.671070                68.708138
# 2          9.537965           5.0051        0.803385                65.905174
# 3          9.810955           5.9747        0.900568                68.803802
# 4          9.100476           4.6768        0.757479                66.750656
# ..              ...              ...             ...                      ...
# 131        8.977794           5.0532        0.890408                66.505341
# 132        8.809546           5.3535        0.849987                67.952736
# 133        7.759683           3.5274        0.817981                56.727283
# 134        8.224720           3.7594        0.698824                55.299377
# 135        7.865712           3.2992        0.763093                55.617260
#
#      freedom_of_choice  generosity  perceptions_of_corruption
# 0             0.396573   -0.096429                   0.933687
# 1             0.781994   -0.042309                   0.896304
# 2             0.466611   -0.121105                   0.735485
# 3             0.831132   -0.194914                   0.842010
# 4             0.712018   -0.138780                   0.773545
# ..                 ...         ...                        ...
# 131           0.623278   -0.169091                   0.837038
# 132           0.939593   -0.094533                   0.796421
# 133           0.599920   -0.157735                   0.800288
# 134           0.806500    0.078037                   0.801290
# 135           0.711458   -0.072064                   0.810237
#
# [136 rows x 10 columns]

# %%
world_covid = pd.read_sql("SELECT * FROM world_covid_data", conn )
world_covid
# Out:
#        covid_cases_id  country_id        date  new_cases  new_deaths  \
# 0                  30       30000  2020-02-24          1           0
# 1                  31       30000  2020-09-22         22           1
# 2                  32       30000  2020-09-21         30           3
# 3                  33       30000  2020-09-20        125           4
# 4                  34       30000  2020-09-19         22           0
# ...               ...         ...         ...        ...         ...
# 41669           59829       30185  2020-06-20          0           0
# 41670           59830       30185  2020-06-19         16           0
# 41671           59831       30185  2020-06-18         62           0
# 41672           59832       30185  2020-08-09         74           2
# 41673           59833       30185  2020-12-31        242           3
#
#        extreme_poverty  handwashing_facilities  covid_times_life_expectancy
# 0                    0                      38                           65
# 1                    0                      38                           65
# 2                    0                      38                           65
# 3                    0                      38                           65
# 4                    0                      38                           65
# ...                ...                     ...                          ...
# 41669               21                      37                           61
# 41670               21                      37                           61
# 41671               21                      37                           61
# 41672               21                      37                           61
# 41673               21                      37                           61
#
# [41674 rows x 8 columns]

# %%
gov_resp = pd.read_sql("SELECT * FROM gov_response", conn )
gov_resp
# Out:
#        response_id  country_id gov_resp_date  \
# 0              300       30000    2020-03-06
# 1              402       30000    2020-03-26
# 2              403       30000    2020-03-28
# 3              404       30000    2020-03-29
# 4              406       30000    2020-04-05
# ...            ...         ...           ...
# 16057        21552       30185    2020-08-20
# 16058        21555       30185    2020-05-02
# 16059        21556       30185    2020-05-02
# 16060        21558       30185    2020-07-22
# 16061        21584       30185    2020-03-17
#
#                                            gov_resp_desc  \
# 0      March 6, Afghanistan "Measures have been taken...
# 1      "On 26 March, the President of Afghanistan, As...
# 2      In Afghanistan's "eastern province of Nangarha...
# 3      Relaxation in the measured lockdown policies i...
# 4      The governor of Afghanistan's capital, Kabul, ...
# ...                                                  ...
# 16057  Every hotel in Zimbabwe shall dedicate a room ...
# 16058  All vehicles used as a transport service in Zi...
# 16059  Every individual must be temperature-tested an...
# 16060  When an employee tests positive for COVID-19 i...
# 16061  In Zimbabwe, the Zimbabwe International Trade ...
#
#                                                 enforcer  \
# 0                    Ministry/Department of Health,Other
# 1                                       National Governm
# 2                               Provincial/State Governm
# 3                               Provincial/State Governm
# 4      National Government,Military,Provincial/State ...
# ...                                                  ...
# 16057                                   National Governm
# 16058                               National Government,
# 16059                                   National Governm
# 16060                               National Government,
# 16061                                   National Governm
#
#                          gov_resp_type  \
# 0         Anti-Disinformation Measures
# 1             Other Policy Not Listed
# 2             Other Policy Not Listed
# 3             Other Policy Not Listed
# 4             Other Policy Not Listed
# ...                                ...
# 16057                 Health Resources
# 16058                           Hygien
# 16059                           Hygien
# 16060                           Hygien
# 16061  Restrictions of Mass Gatherings
#
#                                        gov_resp_link_src
# 0      https://www.etilaatroz.com/94246/fears-rumors-...
# 1      https://reliefweb.int/report/afghanistan/afgha...
# 2      https://www.nytimes.com/2020/03/31/world/asia/...
# 3      https://reliefweb.int/report/afghanistan/afgha...
# 4       https://www.bbc.com/persian/afghanistan-52171203
# ...                                                  ...
# 16057               https://www.veritaszim.net/node/4387
# 16058  http://www.veritaszim.net/sites/veritas_d/file...
# 16059  http://www.veritaszim.net/sites/veritas_d/file...
# 16060  https://www.veritaszim.net/sites/veritas_d/fil...
# 16061  https://iharare.com/independence-day-zitf-post...
#
# [16062 rows x 7 columns]

# %%
conn.close()
